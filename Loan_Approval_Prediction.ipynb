# %% [markdown]
# <a href="https://colab.research.google.com/github/ruchit0002/Loan-Approval-Prediction/blob/main/Loan_Approval_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-bb62f84c-c68c-459c-a4df-1ba10bdfe85d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bb62f84c-c68c-459c-a4df-1ba10bdfe85d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d owner_name/ altruistdelhite04/loan-prediction-problem-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/altruistdelhite04/loan-prediction-problem-dataset
# License(s): unknown
# ...
#   0% 0.00/12.6k [00:00<?, ?B/s]
# 100% 12.6k/12.6k [00:00<00:00, 27.1MB/s]

# %%
# !unzip loan-prediction-problem-dataset.zip
# Out:
# Archive:  loan-prediction-problem-dataset.zip
#   inflating: test_Y3wMUE5_7gLdaTN.csv
#   inflating: train_u6lujuX_CVtuZ9i.csv

# %%
# !mv train_u6lujuX_CVtuZ9i.csv loan_dataset.csv

# %%
import pandas as pd

data = pd.read_csv("loan_dataset.csv")
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...
